# %%
import random
random.randint(50,100)
# Out:
# 82

# %%
stu1 = []
for _ in range(5):
    stu1.append(random.randint(50,100))
stu1
# Out:
# [81, 86, 56, 59, 71]

# %%
students = list()
for _ in range(50):
    students.append([50,60,70,80,90])
students
# Out:
# [[50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
#  [50, 60, 70, 80, 90],
# ...

# %%
students = []
for _ in range(50):
    stu = list()
    for _ in range(5):
        stu.append(random.randint(50,100))
    students.append(stu)
students
# Out:
# [[96, 76, 60, 94, 63],
#  [78, 100, 63, 80, 77],
#  [95, 54, 98, 66, 63],
#  [81, 90, 88, 57, 88],
#  [60, 56, 74, 56, 97],
#  [89, 72, 65, 84, 74],
#  [87, 70, 95, 72, 82],
#  [56, 72, 98, 88, 51],
#  [54, 75, 91, 94, 97],
#  [69, 78, 80, 75, 64],
#  [69, 99, 98, 86, 99],
#  [59, 85, 91, 84, 62],
#  [57, 94, 75, 66, 67],
#  [63, 93, 61, 70, 69],
#  [77, 61, 66, 92, 91],
#  [88, 61, 100, 66, 98],
#  [72, 89, 83, 76, 61],
#  [96, 62, 77, 65, 74],
#  [60, 76, 77, 77, 62],
#  [90, 64, 57, 86, 90],
#  [87, 55, 69, 65, 71],
#  [81, 94, 72, 58, 79],
#  [75, 50, 96, 81, 81],
#  [73, 81, 88, 78, 96],
#  [84, 67, 55, 94, 94],
#  [94, 99, 72, 76, 83],
#  [87, 85, 94, 65, 78],
#  [67, 100, 97, 89, 65],
#  [93, 85, 91, 69, 58],
#  [97, 74, 50, 96, 70],
#  [63, 54, 94, 97, 99],
#  [79, 53, 69, 100, 95],
#  [97, 55, 80, 89, 72],
#  [85, 70, 89, 68, 54],
#  [91, 84, 80, 74, 69],
#  [90, 86, 90, 80, 67],
#  [78, 64, 77, 99, 89],
#  [81, 96, 53, 98, 60],
#  [87, 89, 73, 69, 91],
# ...
