# %%
#codespace要安裝中文字型
#命令列:sudo apt-get update -y
#命令列:sudo apt-get install -y fonts-wqy-zenhei
#字型位置:/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc

import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
font=FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=8)
font1=FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=12)

student1 = {'國文':65,'英文':81,'數學':61,'歷史':43,'探索':71}
student2 = {'國文':53,'英文':84,'數學':71,'歷史':49,'探索':50}

subjects = list(student1.keys())
value1 = list(student1.values())
value2 = list(student2.values())

#製表
fig = plt.figure(figsize=(8,5), dpi=250, facecolor='#cccccc')
ax= fig.add_subplot(1,1,1)
ax.set_title('學生1和學生2的成績比較表',fontproperties=font1)
ax.set_xlabel('科目',fontproperties=font)
ax.set_ylabel('分數',fontproperties=font)

#畫線
ax.plot(subjects,value1,'c-.o')
ax.plot(subjects,value2,'r--o')
ax.set_xticklabels(subjects,fontproperties=font)

#顯示對應的分數
x_locations = ax.get_xticks()
#y_locations = ax.get_yticks()

for i in range(len(x_locations)):
    ax.annotate(str(value1[i]),(x_locations[i]+0.03,value1[i]))
    ax.annotate(str(value2[i]),(x_locations[i]+0.03,value2[i]))

#顯示總分
value1_total = 0
value2_total = 0
for score in value1:
    value1_total += score
for score in value2:
    value2_total += score
ax.annotate(f'學生1總分:{value1_total}\n學生2總分:{value2_total}',(2.7,70),fontproperties=font)
ax.legend([f'學生1:{value1_total}',f'學生2:{value2_total}'],prop=font)

#增加輔助線
ax.grid(axis='y')

#呈現表
plt.show()
# Out:
# /tmp/ipykernel_14240/2931387595.py:28: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(subjects,fontproperties=font)

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
font=FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=8)
font1=FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=12)

student1 = {'國文':65,'英文':81,'數學':61,'歷史':43,'探索':71}
student2 = {'國文':53,'英文':84,'數學':71,'歷史':49,'探索':50}

subjects = list(student1.keys())
value1 = list(student1.values())
value2 = list(student2.values())

#製表
fig = plt.figure(figsize=(8,5), dpi=250, facecolor='#cccccc')
ax= fig.add_subplot(1,1,1)
ax.set_title('學生1和學生2的成績比較表',fontproperties=font1)
ax.set_xlabel('科目',fontproperties=font)
ax.set_ylabel('分數',fontproperties=font)

#畫線
ax.plot(subjects,value1,'c-.o')
ax.plot(subjects,value2,'r--o')
ax.set_xticklabels(subjects,fontproperties=font)

#顯示對應的分數
x_locations = ax.get_xticks()
#y_locations = ax.get_yticks()

for i in range(len(x_locations)):
    ax.annotate(str(value1[i]),(x_locations[i]+0.03,value1[i]))
    ax.annotate(str(value2[i]),(x_locations[i]+0.03,value2[i]))

#顯示總分
value1_total = 0
value2_total = 0
for score in value1:
    value1_total += score
for score in value2:
    value2_total += score
ax.annotate(f'學生1總分:{value1_total}\n學生2總分:{value2_total}',(2.7,70),fontproperties=font)
ax.legend([f'學生1:{value1_total}',f'學生2:{value2_total}'],prop=font)

#增加輔助線
ax.grid(axis='y')

#特寫表格重點
ax.axis(xmin=2.5,xmax=3.5,ymin=35,ymax=60)

#呈現表
plt.show()
# Out:
# /tmp/ipykernel_14240/2080245242.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(subjects,fontproperties=font)
